# %%
import seaborn as sns

# %%
#inside seaborn it has some in built dataset
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# how sepel length is grow w.r.t petal length or sepal width
sns.scatterplot(x=iris.sepal_length,y=iris.sepal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#this state both increase parallelly

# %%
sns.scatterplot(x=iris.sepal_length,y=iris.petal_length)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# Histogram x axis category and y axis frequency
sns.displot(iris['sepal_length'])

# %%
sns.displot(iris.sepal_length)  #Histogram displ0t

# %%
# high occurance to 5.5 to 6.5

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# total bill vs tips

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# yes high bill ---> more tip

# %%
 tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
 #count  for smoker and non smoker

# %%
tips['smoker'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 tips['smoker'].value_count()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
# to visualize this with total bill and tip
# use relational plot function
sns.relplot(x=tips['total_bill'],y=tips['tip'],data=tips,hue='smoker')



# hue is used for color representation it is the groupby operator i.e somker by blue and orange for non smoker

# %%
# to base on sizes 
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],data=tips,hue='size')

# %%
# segragate by colors

# %%
#another parameter 'style' based on symbols
sns.relplot(x=tips['total_bill'],y=tips['tip'],data=tips,style='smoker')

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],data=tips,style='size')

# %%
# time column's hue and size column's style
sns.relplot(x=tips['total_bill'],y=tips.tip,data=tips,style='size',hue='time')

# %%
# on which day person come more
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# so day column have catagorical data
sns.catplot(x='day',y='total_bill',data=tips)

# %%
#so restrunt opens on thur,fri,sat and sunday so saturday lot of customer

# %%
sns.catplot(x='smoker',y='tip',data=tips)

# %%
#from non smoker more tip but high from smoker

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip)

# %%
# jointplot is combination of histogram and scatterplot

# %%
sns.pairplot(tips)

# %% [markdown]
# pairplot is send for all graph of numerical columns ; each one vs each one on single spot

# %%
sns.pairplot(iris #datasetname)
# Out:
#   Cell In[44], line 1
#     sns.pairplot(iris #datasetname)
#                                    ^
# SyntaxError: incomplete input

# %%
sns.pairplot(iris)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the flights dataset
flights = sns.load_dataset('flights')

# Pivot the data to create a matrix format suitable for a heatmap
flights_pivot = flights.pivot('month', 'year', 'passengers')

# Create the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(flights_pivot, annot=True, fmt="d", cmap='YlGnBu')

# Set the title
plt.title('Heatmap of Monthly Flight Passengers from 1949 to 1960')

# Show the plot
plt.show()
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_16396\3992118172.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_pivot = flights.pivot('month', 'year', 'passengers')
